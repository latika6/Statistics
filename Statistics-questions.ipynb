# %%
Here's a list of 100 practice questions for data science using Python. These questions cover various statistical concepts commonly used in data science:

1. Calculate the mean, median, and mode of a given dataset.
2. Calculate the variance and standard deviation of a dataset.
3. Generate a random sample from a normal distribution with a given mean and standard deviation.
4. Calculate the correlation coefficient between two variables.
5. Perform a hypothesis test for the difference between two population means.
6. Perform a chi-square test of independence for two categorical variables.
7. Calculate the probability of a given event occurring in a binomial distribution.
8. Fit a linear regression model to a dataset and interpret the coefficients.
9. Create a histogram of a dataset and determine the appropriate number of bins.
10. Calculate the confidence interval for a population mean.
11. Perform a t-test for the difference between two population means.
12. Perform a one-way ANOVA test to compare the means of more than two groups.
13. Calculate the odds ratio for a 2x2 contingency table.
14. Use the Shapiro-Wilk test to check the normality of a dataset.
15. Perform a Mann-Whitney U test to compare the medians of two groups.
16. Calculate the interquartile range (IQR) of a dataset.
17. Create a boxplot of a dataset to visualize the distribution.
18. Perform a Kruskal-Wallis H test to compare the medians of more than two groups.
19. Calculate the coefficient of determination (R-squared) for a linear regression model.
20. Perform a logistic regression analysis to predict a binary outcome.
21. Use the Kolmogorov-Smirnov test to compare two distributions.
22. Calculate the mean squared error (MSE) of a regression model.
23. Perform a paired t-test for the difference between paired samples.
24. Calculate the cumulative distribution function (CDF) of a given distribution.
25. Perform a two-sample t-test for the difference between two independent samples.
26. Calculate the point estimate and margin of error for a confidence interval.
27. Use the Anderson-Darling test to test for normality.
28. Perform a log-rank test for the difference between survival curves.
29. Calculate the harmonic mean of a set of numbers.
30. Perform a Tukey's range test to identify differences between group means.
31. Use the Q-Q plot to check for normality of a dataset.
32. Calculate the Mahalanobis distance between two points.
33. Perform a Wald test to test the significance of a coefficient in a regression model.
34. Calculate the geometric mean of a set of numbers.
35. Perform a Wilcoxon signed-rank test for paired samples.
36. Use the Jarque-Bera test to test for normality.
37. Calculate the Akaike Information Criterion (AIC) for a regression model.
38. Perform a Brown-Forsythe test for the equality of group variances.
39. Calculate the Bonferroni correction for multiple comparisons.
40. Use the Durbin-Watson statistic to test for autocorrelation in a time series.
41. Perform a Friedman test for the difference between multiple paired samples.
42. Calculate the coefficient of variation (CV) for a dataset.
43. Use the Lilliefors test to test for normality.
44. Perform a Kruskal-Wallis test for the difference between multiple independent samples.
45. Calculate the Gini coefficient for a distribution.
46. Use the Breusch-Pagan test to test for heteroscedasticity in a regression model.
47. Perform a Shapiro-Francia test to test for normality.
48. Calculate the Jensen-Shannon divergence between two probability distributions.
49. Use the Dickey-Fuller test to test for stationarity in a time series.
50. Perform a Bartlett's test for the equality of group variances.
51. Calculate the Cohen's d effect size for the difference between two means.
52. Use the Cramer's V statistic to measure the strength of association between two categorical variables.
53. Perform a Tukey's post hoc test following an ANOVA.
54. Calculate the Spearman rank correlation coefficient between two variables.
55. Use the Anderson-Darling test to test for exponentiality.
56. Perform a likelihood ratio test for the difference between nested models.
57. Calculate the Kendall tau rank correlation coefficient between two variables.
58. Use the Hosmer-Lemeshow test to assess the goodness of fit of a logistic regression model.
59. Perform a Wald-Wolfowitz runs test for randomness.
60. Calculate the Pearson correlation coefficient between two variables.
61. Use the Ansari-Bradley test to compare the variances of two samples.
62. Perform a Ljung-Box test for autocorrelation in a time series.
63. Calculate the Kullback-Leibler divergence between two probability distributions.
64. Use the Diebold-Mariano test to compare the forecast accuracy of two models.
65. Perform a Cochran's Q test for the difference between multiple related samples.
66. Calculate the Youden's J statistic for a binary classification test.
67. Use the D’Agostino-Pearson omnibus test to test for normality.
68. Perform a Portmanteau test for autocorrelation in a time series.
69. Calculate the F1 score for a binary classification test.
70. Use the Anscombe quartet to demonstrate the importance of visualizing data.
71. Perform a Hosmer-Lemeshow goodness-of-fit test for logistic regression.
72. Calculate the G-test of independence for two categorical variables.
73. Use the Davies–Bouldin index to evaluate the clustering of data.
74. Perform a Crame´r’s V test of association for contingency tables.
75. Calculate the Bhattacharyya distance between two probability distributions.
76. Use the Augmented Dickey-Fuller test to test for a unit root in a time series.
77. Perform a t-test for the difference between two means of paired data.
78. Calculate the AUC-ROC score for a binary classification test.
79. Use the Akaike Information Criterion (AIC) for model selection.
80. Perform a Dunn's test for post hoc analysis following a Kruskal-Wallis test.
81. Calculate the Adjusted R-squared for a linear regression model.
82. Use the Anderson-Darling test to test for normality.
83. Perform a Friedman test for the difference between multiple related samples.
84. Calculate the Ljung-Box test statistic for a time series.
85. Use the Dickey-Fuller test to test for unit root in a time series.
86. Perform a Mann-Whitney U test for the difference between two independent samples.
87. Calculate the Bayes factor for model comparison.
88. Use the Bartlett's test to test for homogeneity of variances.
89. Perform a Log-rank test for survival analysis.
90. Calculate the RMSE (Root Mean Squared Error) for a regression model.
91. Use the Wilcoxon signed-rank test for paired samples.
92. Perform a Q-Q plot to check for normality.
93. Calculate the skewness of a distribution.
94. Use the Kolmogorov-Smirnov test to compare two distributions.
95. Perform a Shapiro-Wilk test for normality.
96. Calculate the Mann-K
